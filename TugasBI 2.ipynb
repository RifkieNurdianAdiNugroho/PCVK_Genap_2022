# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
countries = ('Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Falkland Islands', 'French Guiana', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela')

# %%
Population =(45076704, 11626410,212162757,19109629,50819826,17579085,3481,287750,785409,7107305,32880332,585169,3470475,28258770)

# %%
x_coords = np.arange(len(countries))
plt.bar(x_coords, Population)
plt.show()

# %%
x_coords = np.arange(len(countries))
plt.bar(x_coords, Population, tick_label=countries)
plt.xticks(rotation=90)
plt.ylabel('Popoulation (Millions)')
plt.title('South American Population')
plt.show()

# %%
df = pd.DataFrame({
    'Country':countries,
    'Population':Population,
})
df.sort_values(by='Population', inplace=True)

x_coords = np.arange(len(df))
colors = ['#0000FF' for _ in range(len(df))]
colors[-2] = '#FF0000'
plt.bar(x_coords, df['Population'], tick_label=df['Country'], color=colors)
plt.xticks(rotation=90)
plt.ylabel('Popoulation (Millions)')
plt.title('South American Population')
plt.show()
