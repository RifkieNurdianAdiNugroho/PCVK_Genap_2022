# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
countries = ('Bangladesh', 'Brazil', 'China', 'India', 'Indonesia', 'Japan', 'Mexico', 'Nigeria', 'Pakistan', 'Russia', 'United States')
gdp = [2421, 13418, 4353, 9475, 7378, 35477, 14276, 5087, 4133, 20255, 49267]
population = [148692131, 194946470, 1341335152, 1224614327, 239870937, 126535920, 113423047, 158423182, 173593383, 142958164, 310383948]

# %%
plt.scatter(population, gdp)
plt.show()

# %%
lemon_diameter = [6.44, 6.87, 7.7, 8.85, 8.15, 9.96, 7.21, 10.04, 10.2, 11.06]
lemon_weight = [112.05, 114.58, 116.71, 117.4, 128.93, 132.93, 138.92, 
                145.98, 148.44, 152.81]

# %%
lime_diameter = [6.15, 7.0, 7.0, 7.69, 7.95, 7.51, 10.46, 8.72, 9.53, 10.09]
lime_weight = [112.76, 125.16, 131.36, 132.41, 138.08, 142.55, 156.86, 
               158.67, 163.28, 166.74]

# %%
plt.title('Lemons vs. Limes')
plt.xlabel('Diameter (cm)')
plt.ylabel('Weight (g)')
plt.scatter(lemon_diameter, lemon_weight)
plt.scatter(lime_diameter, lime_weight)
plt.show()
